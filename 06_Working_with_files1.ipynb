# %% [markdown]
# `Files with Python`
#
# - [Files with Python](https://www.youtube.com/watch?v=DrmZ4SL6NCo&t=22s)

# %% [markdown]
# `The photos problem`
#
# - [The photos problem](https://www.youtube.com/watch?v=0E5emNEtN-o)

# %% [markdown]
# `Planning the solution to the photos problem`
#
# - [Planning the solution to the photos problem](https://www.youtube.com/watch?v=z5vmzOemnD8)

# %% [markdown]
# `The os module`
# - [The os module](https://www.youtube.com/watch?v=OV9OczW4MeY&t=56s)
#
# - [python OS doc](https://docs.python.org/3/library/os.html?highlight=os#module-os)

# %%
import os

# List files in a directory
os.listdir()
# Out:
# ['photos.zip',
#  '.DS_Store',
#  '02_Python_Basics_with_Turtles.py',
#  'test',
#  '06_Working_with_files1.ipynb',
#  '04_Python_Basics_with_Turtles.py',
#  '03_Python_Basics_with_Turtles.py',
#  '05_Python_Basics_Function.ipynb',
#  'README.md',
#  '07_organize_photos.py',
#  '01_Python_Basics_with_Turtles.py',
#  '.git',
#  'Photos']

# %%
# Make a new directory
os.mkdir("test")

# %%
'''
os.remove(path, *, dir_fd=None)
Remove (delete) the file path. If path is a directory, an OSError is raised. Use rmdir() to remove directories. If the file does not exist, a FileNotFoundError is raised.
'''
os.rmdir("test")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Move a file from one directory to another
os.rename('test1.txt','test/test1.txt')

# %% [markdown]
# `Functions on Files and Directories`
#
# - [Functions on Files and Directories](https://www.youtube.com/watch?v=emrOq6uWqVo&t=212s)

# %%
import os
os.listdir("Photos")
# Out:
# ['2017-04-02_Brooklyn_23:15:06.jpg',
#  '2016-11-29_Berlin_04:32:38.jpg',
#  '2016-09-04_Berlin_08:25:50.jpg',
#  '2018-12-18_Yosemite_11:00:17.jpg',
#  '2017-04-02_Berlin_01:35:36.jpg',
#  '2018-08-01_Oahu_21:51:37.jpg',
#  '2017-09-27_Firenze_03:49:17.jpg',
#  '2018-02-12_Scotland_00:05:24.jpg',
#  '2017-06-20_Yosemite_12:17:53.jpg',
#  '2018-01-08_Scotland_15:13:29.jpg',
#  '2018-07-28_Berlin_02:38:04.jpg',
#  '2018-06-27_Kyoto_22:14:01.jpg',
#  '2017-01-13_Yosemite_03:36:50.jpg',
#  '2017-02-35_Kyoto_18:12:25.jpg',
#  '2018-01-23_Cancun_01:46:43.jpg',
#  '2018-05-17_Cancun_06:43:19.jpg',
#  '2018-11-05_Kyoto_17:12:22.jpg',
#  '2018-06-10_Cancun_20:42:07.jpg',
#  '2018-10-28_Firenze_10:00:18.jpg',
#  '2016-11-04_Berlin_09:42:22.jpg',
#  '2017-10-10_Brooklyn_22:09:38.jpg',
#  '2018-02-09_Kyoto_19:11:24.jpg',
#  '2017-06-29_Firenze_22:01:03.jpg',
#  '2018-08-16_Oahu_22:12:06.jpg',
#  '2018-02-07_Kyoto_17:42:59.jpg',
#  '2018-01-03_Scotland_21:51:57.jpg',
# ...

# %% [markdown]
# `Relative Paths and the Current Working Directory`
#
# - [working directory](https://www.youtube.com/watch?v=V-6HnY6BL9Y&t=7s)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import 
# We can use os.getcwd to get the current working directory:
os.getcwd()
# Out:
# '/Users/pl157r/gitrepo_personal/Intro_PythonII'

# %%
# And we can use os.chdir to change to a different directory:
os.chdir("Photos")

# %%
os.getcwd()
# Out:
# '/Users/pl157r/gitrepo_personal/Intro_PythonII/Photos'

# %%
# An alternative would be to use an absolute path, like this:
os.chdir('/Users/pl157r/gitrepo_personal/Intro_PythonII/Photos')
os.getcwd()
# Out:
# '/Users/pl157r/gitrepo_personal/Intro_PythonII/Photos'

# %% [markdown]
# `os functions and shell commands`
#
# - [bash vs python os function](https://www.youtube.com/watch?v=HzPHAFFcJPo&t=1s)

# %%
# Here's an example with os.path.join that you can try in the Python interpreter on
os.path.join("Documents","Photos","Oahu")
# Out:
# 'Documents/Photos/Oahu'

# %% [markdown]
# `Extract the place names (1/4)`
#
# - [Extract Place Name](https://www.youtube.com/watch?v=breYyDpTEU8&t=42s)

# %%
os.getcwd()
# Out:
# '/Users/pl157r/gitrepo_personal/Intro_PythonII/Photos'

# %%
os.chdir("/Users/pl157r/gitrepo_personal/Intro_PythonII/")

# %%
import os

#os.chdir("Photos")
originals = os.listdir()

def extract_place(file_names):
    for name in file_names:
     place_name = name.split("_")[1]
     print(place_name)

extract_place(originals)

print(originals)
# Out:
# Brooklyn
# Berlin
# Berlin
# Yosemite
# Berlin
# Oahu
# Firenze
# Scotland
# Yosemite
# Scotland
# Berlin
# Kyoto
# Yosemite
# Kyoto
# Cancun
# Cancun
# Kyoto
# Cancun
# Firenze
# Berlin
# Brooklyn
# Kyoto
# Firenze
# Oahu
# Kyoto
# Scotland
# Cancun
# ...

# %%
name = '2016-11_Berlin_04:32:38.jpg'
name[8:14]
# Out:
# 'Berlin'

# %%
name = '2017-06_Yosemite_12:17:53.jpg'
name[8:14]
# Out:
# 'Yosemi'

# %%
name = '2018-01_Oahu_22:12:06.jpg'
name[8:14]
# Out:
# 'Oahu_2'

# %%
name = '2018_Scottland_1.jpg'
name[8:14]
# Out:
# 'ttland'

# %%
filename = "2016-11-04_Berlin_09/42/22.jpg"

filename.count("_")
# Out:
# 2

# %%
"_" in filename
# Out:
# True

# %%
filename.find("_")
# Out:
# 10

# %%
filename = "2016-11-04_Berlin_09/42/22.jpg"
first = filename.find('_')

filename[first:]
# Out:
# '_Berlin_09/42/22.jpg'

# %%
filename[first+1:]
# Out:
# 'Berlin_09/42/22.jpg'

# %%
filename[:first]
# Out:
# '2016-11-04'

# %%
filename[:first+1]
# Out:
# '2016-11-04_'

# %%
filename = "2016-11-04_Berlin_09/42/22.jpg"
first = filename.find('_')

partial = filename[first+1:]
partial
# Out:
# 'Berlin_09/42/22.jpg'

# %%
second = partial.find("_") # The second underscore is at index 6
partial[:second] # Get slice from the beginning up to the second underscore
# Out:
# 'Berlin'

# %%
filename = "2018-01-03_Oahu_21/51/57.jpg"
first = filename.find("_")
first
# Out:
# 10

# %%
partial = filename[first+1:]
partial
# Out:
# 'Oahu_21/51/57.jpg'

# %%
second = partial.find("_")
second
# Out:
# 4

# %%
partial[:second]
# Out:
# 'Oahu'

# %% [markdown]
# `Extract the place names (2/4)`

# %%
def extract_place(filename):
    first = filename.find("_")
    partial = filename[first+1:]
    second = partial.find("_")
    place_name = partial[:second]
    return place_name

# %%
print(extract_place("2016-11-04_Berlin_09/42/22.jpg"))
print(extract_place("2018-01-03_Oahu_21/51/57.jpg"))
print(extract_place("2018-01_Scottland_11/51/27.jpg"))
# Out:
# Berlin
# Oahu
# Scottland

# %%
def extract_place(filename):
    first = filename.find("_")
    partial = filename[first+1:]
    second = partial.find("_")
    return partial[:second]

# Here are some calls you can use for testing:
print(extract_place("2016-11-04_Berlin_09/42/22.jpg"))
print(extract_place("2018-01-03_Oahu_21/51/57.jpg"))
print(extract_place("2018-01_Scottland_11/51/27.jpg"))
# Out:
# Berlin
# Oahu
# Scottland

# %% [markdown]
# `Extract the place names (3/4)`
#
#  - As you can see, the split method does just what the name implies—it splits a string up and returns a list containing the parts.

# %%
# The split method
"ba_na_na".split("_")
# Out:
# ['ba', 'na', 'na']

# %%
"banana".split("n")
# Out:
# ['ba', 'a', 'a']

# %%
sentence = "a banana split"
sentence.split(" ")
# Out:
# ['a', 'banana', 'split']

# %%
"bandanna".split("dan")
# Out:
# ['ban', 'na']

# %% [markdown]
# `Extract the place names (4/4)`

# %%
def extract_place(filename):
    parts = filename.split("_") # Get a list containing all the parts
    place_name = parts[1] # Use the index operator to select the second list item
    return place_name

# %%
def extract_place(filename):
    return filename.split("_")[1]

# %%
print(extract_place("2016-11-04_Berlin_09/42/22.jpg"))
print(extract_place("2018-01-03_Oahu_21/51/57.jpg"))
print(extract_place("2018-01_Scottland_11/51/27.jpg"))
# Out:
# Berlin
# Oahu
# Scottland

# %% [markdown]
# `Python: extract_place solution`
# - [string extract](https://www.youtube.com/watch?v=KTqScwzhkKA&t=1s)

# %% [markdown]
# `Make place directories (1/4)`

# %%
import os

def extract_place(filename):
    return filename.split("_")[1]

#os.chdir("Photos")
originals = os.listdir()

places = [] # This is the new list we are adding

for filename in originals:
    places.append(extract_place(filename))

print(places)
# Out:
# ['Brooklyn', 'Berlin', 'Berlin', 'Yosemite', 'Berlin', 'Oahu', 'Firenze', 'Scotland', 'Yosemite', 'Scotland', 'Berlin', 'Kyoto', 'Yosemite', 'Kyoto', 'Cancun', 'Cancun', 'Kyoto', 'Cancun', 'Firenze', 'Berlin', 'Brooklyn', 'Kyoto', 'Firenze', 'Oahu', 'Kyoto', 'Scotland', 'Cancun']

# %% [markdown]
# `Make place directories (2/4)`

# %%
import os

def extract_place(filename):
    return filename.split("_")[1]

def make_place_directories(places):
    for place in places:
        os.mkdir(place)

#os.chdir("Photos")
originals = os.listdir()

places = [] # This is the new list we are adding

for filename in originals:
    places.append(extract_place(filename))

# Function call
unique_places = set(places)
#print(unique_places)
make_place_directories(unique_places)

print(os.listdir())
# Out:
# ['2017-04-02_Brooklyn_23:15:06.jpg', '2016-11-29_Berlin_04:32:38.jpg', '2016-09-04_Berlin_08:25:50.jpg', '2018-12-18_Yosemite_11:00:17.jpg', '2017-04-02_Berlin_01:35:36.jpg', '2018-08-01_Oahu_21:51:37.jpg', '2017-09-27_Firenze_03:49:17.jpg', '2018-02-12_Scotland_00:05:24.jpg', 'Cancun', '2017-06-20_Yosemite_12:17:53.jpg', '2018-01-08_Scotland_15:13:29.jpg', '2018-07-28_Berlin_02:38:04.jpg', '2018-06-27_Kyoto_22:14:01.jpg', '2017-01-13_Yosemite_03:36:50.jpg', '2017-02-35_Kyoto_18:12:25.jpg', 'Scotland', '2018-01-23_Cancun_01:46:43.jpg', '2018-05-17_Cancun_06:43:19.jpg', 'Kyoto', '2018-11-05_Kyoto_17:12:22.jpg', '2018-06-10_Cancun_20:42:07.jpg', '2018-10-28_Firenze_10:00:18.jpg', '2016-11-04_Berlin_09:42:22.jpg', 'Firenze', '2017-10-10_Brooklyn_22:09:38.jpg', '2018-02-09_Kyoto_19:11:24.jpg', 'Berlin', 'Yosemite', 'Brooklyn', '2017-06-29_Firenze_22:01:03.jpg', '2018-08-16_Oahu_22:12:06.jpg', '2018-02-07_Kyoto_17:42:59.jpg', 'Oahu', '2018-01-03_Scotland_21:51:57.jpg', '2017-07-30_Cancun_
# ...

# %% [markdown]
# `Make place directories (3/4)`
#
# - https://www.youtube.com/watch?v=NOC6JiN49Dk&t=50s

# %% [markdown]
# `Make place directories (4/4)`

# %%
import os

def extract_place(filename):
    return filename.split("_")[1]

def make_place_directories(places):
    for place in places:
        os.mkdir(place)

#os.chdir("Photos")
originals = os.listdir()

places = [] # This is the new list we are adding
for filename in originals:
    place = extract_place(filename)
    if place not in places: # This is the key change
        places.append(place)

# Function call
make_place_directories(places)

print(os.listdir())
# Out:
# ['2017-04-02_Brooklyn_23:15:06.jpg', '2016-11-29_Berlin_04:32:38.jpg', '2016-09-04_Berlin_08:25:50.jpg', '2018-12-18_Yosemite_11:00:17.jpg', '.DS_Store', '2017-04-02_Berlin_01:35:36.jpg', '2018-08-01_Oahu_21:51:37.jpg', '2017-09-27_Firenze_03:49:17.jpg', '2018-02-12_Scotland_00:05:24.jpg', 'Cancun', '2017-06-20_Yosemite_12:17:53.jpg', '2018-01-08_Scotland_15:13:29.jpg', '2018-07-28_Berlin_02:38:04.jpg', '2018-06-27_Kyoto_22:14:01.jpg', '2017-01-13_Yosemite_03:36:50.jpg', '2017-02-35_Kyoto_18:12:25.jpg', 'Scotland', '2018-01-23_Cancun_01:46:43.jpg', '2018-05-17_Cancun_06:43:19.jpg', 'Kyoto', '2018-11-05_Kyoto_17:12:22.jpg', '2018-06-10_Cancun_20:42:07.jpg', '2018-10-28_Firenze_10:00:18.jpg', '2016-11-04_Berlin_09:42:22.jpg', 'Firenze', '2017-10-10_Brooklyn_22:09:38.jpg', '2018-02-09_Kyoto_19:11:24.jpg', 'Berlin', 'Yosemite', 'Brooklyn', '2017-06-29_Firenze_22:01:03.jpg', '2018-08-16_Oahu_22:12:06.jpg', '2018-02-07_Kyoto_17:42:59.jpg', 'Oahu', '2018-01-03_Scotland_21:51:57.jpg', 'Store
# ...

# %% [markdown]
# `Move the files`

# %%
filename = '2018-08-01_Oahu_21:51:37.jpg'
place = 'Oahu'

# Which of the following would generate the string 'Oahu/2018-08-01_Oahu_21:51:37.jpg'?

os.path.join(place, filename)
# Out:
# 'Oahu/2018-08-01_Oahu_21:51:37.jpg'

# %%
# Like if we wanted to move some_file to the Desktop, we might rename it like this:
filename = '2018-08-01_Oahu_21:51:37.jpg'
place = 'Oahu'

os.rename(filename, os.path.join(place, filename))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[85], line 5
#       2 filename = '2018-08-01_Oahu_21:51:37.jpg'
#       3 place = 'Oahu'
# ----> 5 os.rename(filename, os.path.join(place, filename))
#
# FileNotFoundError: [Errno 2] No such file or directory: '2018-08-01_Oahu_21:51:37.jpg' -> 'Oahu/2018-08-01_Oahu_21:51:37.jpg'

# %%
import os

def extract_place(filename):
    return filename.split("_")[1]

def make_place_directories(places):
    for place in places:
        os.mkdir(place)

#os.chdir("Photos")
originals = os.listdir()

places = [] # This is the new list we are adding
for filename in originals:
    place = extract_place(filename)
    if place not in places: # This is the key change
        places.append(place)

# Function call to create sub-directories
make_place_directories(places)

# Move files to appropriate directories
for filename in originals:
    place = extract_place(filename)
    os.rename(filename, os.path.join(place, filename))

print(os.listdir())
# Out:
# ['Cancun', 'Scotland', 'Kyoto', 'Firenze', 'Berlin', 'Yosemite', 'Brooklyn', 'Oahu', 'Store']

# %% [markdown]
# `Organize photos`
#
# - https://www.youtube.com/watch?v=2V-sqfHjoj0

# %%
os.getcwd()
# Out:
# '/Users/pl157r/gitrepo_personal/Intro_PythonII/Photos'

# %%
os.chdir("/Users/pl157r/gitrepo_personal/Intro_PythonII")

# %%
os.getcwd()
# Out:
# '/Users/pl157r/gitrepo_personal/Intro_PythonII'

# %%
import os

def extract_place(filename):
    return filename.split("_")[1]

def make_place_directories(places):
    for place in places:
        os.mkdir(place)

def organize_photos(directory):
    # first, extract place names.
    os.chdir(directory)
    originals = os.listdir()

    places = [] # This is the new list we are adding
    for filename in originals:
        place = extract_place(filename)
        if place not in places: # This is the key change
            places.append(place)
    
    # Second, make place directories.
    # Function call to create sub-directories.
    make_place_directories(places)

    # Finally, Move files to directories
    for filename in originals:
        place = extract_place(filename)
        os.rename(filename, os.path.join(place, filename))

# %%
import os

def make_place_directories(places): # Here's the function definition
    for place in places:
        os.mkdir(place)

def extract_place(filename):
    return filename.split('_')[1]

def organize_photos(directory):
    os.chdir(directory)
    originals = os.listdir()
    places = []
    for filename in originals:
        place = extract_place(filename)
        if place not in places: # This is the key change
            places.append(place)

    make_place_directories(places)

    for filename in originals:
        place = extract_place(filename)
        os.rename(filename, os.path.join(place, filename))

# Function Call
organize_photos("Photos")

# %% [markdown]
# `The script footer (1/2)`
#
# ```Text
# Suppose that at some point we decide that we would like to use our organize_photos.py code in another program. We've been importing other modules—like turtle, random, and os. Could we do the same thing with organize_photos?
#
# The answer is yes—but there's a slight complication that we'll explain on this page.
#
# ```

# %%
import organize_photos

# %% [markdown]
# `The script footer (2/2)`
#
# - [Double-underscore ("dunder") variables](https://www.youtube.com/watch?v=3GAJlxbhXuk&t=98s)

# %%
import my_script

# %% [markdown]
# `Pycodestyle`
#
# - [Python PROJECT Pycodestyle](https://www.youtube.com/watch?v=LZnjWP9EF6w&t=76s) : The pycodestyle tool helps you write Python code that will be easier to read for other Python programmers — including your project reviewers. It checks your code using many of the rules from the Python style guide.

# %% [markdown]
# ```Text
# Either in the workspace below or on your own computer, go ahead and install pycodestyle. You can do this by using the pip (or pip3) command in the shell, in your terminal:
#
# # If your Python is called "python" (this is what the workspace uses)
# $ pip install pycodestyle
# # If your Python is called "python3"
# $ pip3 install pycodestyle
#
# ```
