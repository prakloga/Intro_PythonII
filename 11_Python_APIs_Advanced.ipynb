# %% [markdown]
# `Learning Advanced API Concepts`
#
# - [Learning Advanced API Concepts](https://realpython.com/python-api/)

# %% [markdown]
# There are a few more advanced topics that are worth touching upon, even if briefly, such as `authentication`, `pagination`, and `rate` limiting.

# %% [markdown]
# `Authentication`
#
# - `API Key`: The most common level of authentication is the API key.
# - These keys are used to identify you as an API user or customer and to trace your use of the API. API keys are typically sent as a request header or as a query parameter.

# %% [markdown]
# [NASA APIs](https://api.nasa.gov/)

# %%
import os
import configparser

# Read credentials.cfg file
config = configparser.ConfigParser()
config.read('credentials.cfg')

NASA_API_KEY = config['API']['NASA']
OPENWEATHER_API_KEY = config['API']['OPENWEATHER']
GITHUB_CLIENT_ID = config['API']['GITHUB_CLIENTID']
GITHUB_CLIENT_SECRETS = config['API']['GITHUB_CLIENTSECRETS']

# %%
import requests

endpoint = "https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos"
api_key = NASA_API_KEY
query_params = {"api_key": api_key, "earth_date":"2020-07-01"} # You can add the API key to your request by appending the api_key= query parameter:

response = requests.get(endpoint, params=query_params)
response.status_code
# Out:
# 200

# %%
# Now have a look at the Response object and try to extract some pictures from it:
response.json()
# Out:
# {'photos': [{'id': 754118,
#    'sol': 2809,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FLB_646868981EDR_F0810628FHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754119,
#    'sol': 2809,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FRB_646868981EDR_F0810628FHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754120,
#    'sol': 2809,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FRB_646860144EDR_F0810628FHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754121,
#    'sol': 2809,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FLB_646860144EDR_F0810628FHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754122,
#    'sol': 2809,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RRB_646869036EDR_F0810628RHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754123,
#    'sol': 2809,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RLB_646869036EDR_F0810628RHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754124,
#    'sol': 2809,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RRB_646860185EDR_F0810628RHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754125,
#    'sol': 2809,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RLB_646860185EDR_F0810628RHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754126,
#    'sol': 2809,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NLB_646869070EDR_F0810628NCAM00229M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754127,
#    'sol': 2809,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NLB_646860211EDR_F0810628NCAM00229M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754128,
#    'sol': 2809,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NRB_646869070EDR_F0810628NCAM00229M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 754129,
#    'sol': 2809,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NRB_646860211EDR_F0810628NCAM00229M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4060,
#     'max_date': '2024-01-07',
#     'total_photos': 692166,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}}]}

# %%
response.json()['photos']
# Out:
# [{'id': 754118,
#   'sol': 2809,
#   'camera': {'id': 20,
#    'name': 'FHAZ',
#    'rover_id': 5,
#    'full_name': 'Front Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FLB_646868981EDR_F0810628FHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754119,
#   'sol': 2809,
#   'camera': {'id': 20,
#    'name': 'FHAZ',
#    'rover_id': 5,
#    'full_name': 'Front Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FRB_646868981EDR_F0810628FHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754120,
#   'sol': 2809,
#   'camera': {'id': 20,
#    'name': 'FHAZ',
#    'rover_id': 5,
#    'full_name': 'Front Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FRB_646860144EDR_F0810628FHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754121,
#   'sol': 2809,
#   'camera': {'id': 20,
#    'name': 'FHAZ',
#    'rover_id': 5,
#    'full_name': 'Front Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FLB_646860144EDR_F0810628FHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754122,
#   'sol': 2809,
#   'camera': {'id': 21,
#    'name': 'RHAZ',
#    'rover_id': 5,
#    'full_name': 'Rear Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RRB_646869036EDR_F0810628RHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754123,
#   'sol': 2809,
#   'camera': {'id': 21,
#    'name': 'RHAZ',
#    'rover_id': 5,
#    'full_name': 'Rear Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RLB_646869036EDR_F0810628RHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754124,
#   'sol': 2809,
#   'camera': {'id': 21,
#    'name': 'RHAZ',
#    'rover_id': 5,
#    'full_name': 'Rear Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RRB_646860185EDR_F0810628RHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754125,
#   'sol': 2809,
#   'camera': {'id': 21,
#    'name': 'RHAZ',
#    'rover_id': 5,
#    'full_name': 'Rear Hazard Avoidance Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RLB_646860185EDR_F0810628RHAZ00337M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754126,
#   'sol': 2809,
#   'camera': {'id': 26,
#    'name': 'NAVCAM',
#    'rover_id': 5,
#    'full_name': 'Navigation Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NLB_646869070EDR_F0810628NCAM00229M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754127,
#   'sol': 2809,
#   'camera': {'id': 26,
#    'name': 'NAVCAM',
#    'rover_id': 5,
#    'full_name': 'Navigation Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NLB_646860211EDR_F0810628NCAM00229M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754128,
#   'sol': 2809,
#   'camera': {'id': 26,
#    'name': 'NAVCAM',
#    'rover_id': 5,
#    'full_name': 'Navigation Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NRB_646869070EDR_F0810628NCAM00229M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#  {'id': 754129,
#   'sol': 2809,
#   'camera': {'id': 26,
#    'name': 'NAVCAM',
#    'rover_id': 5,
#    'full_name': 'Navigation Camera'},
#   'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/ncam/NRB_646860211EDR_F0810628NCAM00229M_.JPG',
#   'earth_date': '2020-07-01',
#   'rover': {'id': 5,
#    'name': 'Curiosity',
#    'landing_date': '2012-08-06',
#    'launch_date': '2011-11-26',
#    'status': 'active',
#    'max_sol': 4060,
#    'max_date': '2024-01-07',
#    'total_photos': 692166,
#    'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#     {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#     {'name': 'MAST', 'full_name': 'Mast Camera'},
#     {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#     {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#     {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#     {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}}]

# %%
photos = response.json()['photos']
print(f"Found {len(photos)} photos")
# Out:
# Found 12 photos

# %%
# For this example, you picked a specific earth_date (2020-07-01) and then a specific photo from the response dictionary (4). 
photos[4]["img_src"]
# Out:
# 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RRB_646869036EDR_F0810628RHAZ00337M_.JPG'

# %% [markdown]
# `OAuth: Getting Started`

# %% [markdown]
# `Example using the GitHub API!`
#
# - [GitHub Creating an OAuth app](https://docs.github.com/en/apps/oauth-apps/building-oauth-apps/creating-an-oauth-app)
#
# - [GitHub API Doc](https://docs.github.com/en/rest?apiVersion=2022-11-28)

# %%
#GITHUB_CLIENT_ID = config['API']['GITHUB_CLIENTID']
#GITHUB_CLIENT_SECRETS = config['API']['GITHUB_CLIENTSECRETS']

# %% [markdown]
# Once you’ve created your app, copy and paste the Client_ID and Client_Secret, together with your selected redirect URL, into a Python file called github.py:

# %%
import requests

# REPLACE the following variables with your Client ID and Client Secret
CLIENT_ID = GITHUB_CLIENT_ID
CLIENT_SECRET = GITHUB_CLIENT_SECRETS

# REPLACE the following variable with what you added in the
# "Authorization callback URL" field
REDIRECT_URI = "https://httpbin.org/anything"

# %% [markdown]
# you need to be able to create a link to redirect the user to their GitHub account, as the GitHub documentation explains:
#
# - [Request a user's GitHub identity](https://docs.github.com/en/apps/oauth-apps/building-oauth-apps/authorizing-oauth-apps#1-request-a-users-github-identity)

# %%
# In this piece of code, you first define the required parameters that the API expects and then call the API using the requests package and .get().
def create_oauth_link():
    params = {
        "client_id":CLIENT_ID
       ,"redirect_uri":REDIRECT_URI
       ,"scope":"user"
       ,"response_type":"code"
    }

    endpoint = "https://github.com/login/oauth/authorize"
    response = requests.get(endpoint, params=params)
    return response.url

# %% [markdown]
# When you make the request to the /login/oauth/authorize endpoint, the API will automatically redirect you to the GitHub website.
# In that case, you want to fetch the url parameter from the response. This parameter contains the exact URL that GitHub is redirecting you to.

# %% [markdown]
# The next step in the authorization flow is to exchange the code you get for an access token. Again, following the steps in GitHub’s documentation, you can make a function for it:
#
# - [Users are redirected back to your site by GitHub](https://docs.github.com/en/apps/oauth-apps/building-oauth-apps/authorizing-oauth-apps#2-users-are-redirected-back-to-your-site-by-github)

# %%
# Here, you make a POST request to exchange the code for an access token. In this request, you have to send your CLIENT_SECRET and code so that GitHub can validate that this specific code was initially generated by your application. 
# Only then will the GitHub API generate a valid access token and return it to you.
def exchange_code_for_access_token(code=None):
    params = {
        "client_id":CLIENT_ID
       ,"client_secret":CLIENT_SECRET
       ,"redirect_uri":REDIRECT_URI
       ,"code":code
    }

    headers = {"Accept":"application/json"}
    endpoint = "https://github.com/login/oauth/access_token"
    response = requests.post(endpoint, params=params, headers=headers).json()
    return response["access_token"]

# %%
# If everything goes according to plan, then you should be rewarded with a valid access token that you can use to make calls to the GitHub API, impersonating the authenticated user.
link = create_oauth_link()
#print(f"Follow the link to start the authentication with GitHub: {link}")
code = input("GitHub code: ")
access_token = exchange_code_for_access_token(code)
#print(f"Exchanged code {code} with access token: {access_token}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       3 #print(f"Follow the link to start the authentication with GitHub: {link}")
#       4 code = input("GitHub code: ")
# ----> 5 access_token = exchange_code_for_access_token(code)
#
# Cell In[15], line 12, in exchange_code_for_access_token(code)
#      10 endpoint = "https://github.com/login/oauth/access_token"
#      11 response = requests.post(endpoint, params=params, headers=headers).json()
# ---> 12 return response["access_token"]
#
# KeyError: 'access_token'

# %% [markdown]
# Now try adding the following code to fetch your user profile using the User API and to print your name, username, and number of private repositories:
# - [User API](https://docs.github.com/en/rest/users?apiVersion=2022-11-28#get-the-authenticated-user)

# %%
# Update the access_token variable with the access token that you received from the previous step:
access_token = ''

# %%
headers = {"Authorization":f"token {access_token}"}
endpoint = "https://api.github.com/user"
response = requests.get(endpoint, headers=headers).json()
#response

# %%
def print_user_info(access_token=None):
    headers = {"Authorization":f"token {access_token}"}
    endpoint = "https://api.github.com/user"
    response = requests.get(endpoint, headers=headers).json()
    name = response["name"]
    username = response["login"]
    private_repos_count = response["total_private_repos"]
    print(f"{name} ({username}) | private repositories: {private_repos_count}")

# %%
#print_user_info(access_token)

# %% [markdown]
# `Pagination`
#
# In very simple terms, `pagination` is the act of splitting large amounts of data into multiple smaller pieces. For example, whenever you go to the questions page in Stack Overflow, you see something like this at the bottom:
#
# `For APIs in particular, this is normally handled with the help of query parameters, mainly the following two:`
#
#  - A `page` attribute that defines which page you’re currently requesting
#  - A `size` attribute that defines the size of each page
#
#
# - [GitHub Public Events API](https://docs.github.com/en/rest/activity?apiVersion=2022-11-28#list-public-events)

# %%
# Using the GitHub API again, you can find an events endpoint in the documentation that contains pagination query parameters. 
# The parameter per_page= defines the number of items to return, and page= allows you to paginate through multiple results. Here’s how to use these parameters:

response = requests.get("https://api.github.com/events?per_page=1&page=0")
response.json()[0]['id']
# Out:
# '34689232177'

# %%
response = requests.get("https://api.github.com/events?per_page=1&page=1")
response.json()[0]['id']
# Out:
# '34689243505'

# %%
response = requests.get("https://api.github.com/events?per_page=1&page=2")
response.json()[0]['id']
# Out:
# '34689263460'

# %% [markdown]
# `Rate Limiting`

# %% [markdown]
# `For the sake of demonstration, you’ll purposefully try to exceed GitHub’s rate limit to see what happens. In the code below, you’ll request data until you get a status code other than 200 OK:`

# %%
endpoint = "https://api.github.com/events"
for i in range(1,6):
    response = requests.get(endpoint, params={"per_page":1,"page":i})
    print(f"{i}: {response.status_code}")
    if response.status_code != 200:
        break
# Out:
# 1: 200
# 2: 200
# 3: 200
# 4: 200
# 5: 200

# %%
# Have a look at the latest response.headers to see if you can find those specific rate-limiting headers.
response.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Tue, 09 Jan 2024 17:39:48 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"5587b40be633d36bc140fff137f6dae942d5bb8155ea100d9bf303b6ecd165a3"', 'Last-Modified': 'Tue, 09 Jan 2024 17:34:48 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?per_page=1&page=4>; rel="prev", <https://api.github.com/events?per_page=1&page=6>; rel="next", <https://api.github.com/events?per_page=1&page=274>; rel="last", <https://api.github.com/events?per_page=1&page=1>; rel="first"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '46', 'X-RateLimit-Reset': '1704824516', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '14', 'Accept-Ranges': 'bytes', 'Content-Length': '478', 'X-GitHub-Request-Id': '7891:80C8:5EAB7:C2E9F:659D84E4', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip'}

# %% [markdown]
# `Consuming APIs With Python: Practical Examples`

# %% [markdown]
# Searching and Fetching Trending GIFs
# How about making a small script that fetches the top three trending GIFs from the GIPHY website? To do this, you need to create an app and get an API key from GIPHY. You can find instructions by expanding the box below, and you can also check GIPHY’s quickstart documentation.
#
# - [giphy](https://giphy.com/)
# - [giphy API Doc](https://developers.giphy.com/docs/api/#quick-start-guide)
# - [giphy API Explorer](https://developers.giphy.com/explorer/)

# %%
import os
import configparser

# Read credentials.cfg file
config = configparser.ConfigParser()
config.read('credentials.cfg')

NASA_API_KEY = config['API']['NASA']
OPENWEATHER_API_KEY = config['API']['OPENWEATHER']
GITHUB_CLIENT_ID = config['API']['GITHUB_CLIENTID']
GITHUB_CLIENT_SECRETS = config['API']['GITHUB_CLIENTSECRETS']
GIPHY_API_KEY = config['API']['GIPHY']

# %%
import requests

# Replace the following with the API Key generated from the Giphy API
# you define the params and add your own API key. You also include a couple of other filters: limit to get 3 results and rating to get only appropriate content.
API_KEY = GIPHY_API_KEY
endpoint = "https://api.giphy.com/v1/gifs/trending"

params = {"api_key":API_KEY, "limit":3, "rating":"g"}
response = requests.get(endpoint, params=params)
response.status_code
# Out:
# 200

# %%
response.headers.get('Content-Type')
# Out:
# 'application/json'

# %%
response.json()
# Out:
# {'data': [{'type': 'gif',
#    'id': 'gRhW4YgNvO6dLeLTf8',
#    'url': 'https://giphy.com/gifs/primevideo-prime-video-saltburn-salt-burn-gRhW4YgNvO6dLeLTf8',
#    'slug': 'primevideo-prime-video-saltburn-salt-burn-gRhW4YgNvO6dLeLTf8',
#    'bitly_gif_url': 'https://gph.is/g/4D0DXMB',
#    'bitly_url': 'https://gph.is/g/4D0DXMB',
#    'embed_url': 'https://giphy.com/embed/gRhW4YgNvO6dLeLTf8',
#    'username': 'Saltburnfilm',
#    'source': '',
#    'title': 'Amazon Thank You GIF by Saltburn',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2024-01-05 18:58:47',
#    'trending_datetime': '2024-01-09 18:00:07',
#    'images': {'original': {'height': '360',
#      'width': '480',
#      'size': '723813',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g',
#      'mp4_size': '88655',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.mp4&ct=g',
#      'webp_size': '123170',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.webp&ct=g',
#      'frames': '29',
#      'hash': '56856552e251a34e5a49f2544ba77797'},
#     'downsized': {'height': '360',
#      'width': '480',
#      'size': '723813',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_large': {'height': '360',
#      'width': '480',
#      'size': '723813',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_medium': {'height': '360',
#      'width': '480',
#      'size': '723813',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_small': {'height': '360',
#      'width': '480',
#      'mp4_size': '88655',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy-downsized-small.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-downsized-small.mp4&ct=g'},
#     'downsized_still': {'height': '360',
#      'width': '480',
#      'size': '723813',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy_s.gif&ct=g'},
#     'fixed_height': {'height': '200',
#      'width': '267',
#      'size': '242954',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.gif&ct=g',
#      'mp4_size': '34351',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.mp4&ct=g',
#      'webp_size': '63308',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.webp&ct=g'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '267',
#      'size': '51282',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200_d.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_d.gif&ct=g',
#      'webp_size': '22232',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200_d.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_d.webp&ct=g'},
#     'fixed_height_small': {'height': '100',
#      'width': '134',
#      'size': '90523',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.gif&ct=g',
#      'mp4_size': '14548',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.mp4&ct=g',
#      'webp_size': '27668',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.webp&ct=g'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '134',
#      'size': '3955',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100_s.gif&ct=g'},
#     'fixed_height_still': {'height': '200',
#      'width': '267',
#      'size': '14874',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_s.gif&ct=g'},
#     'fixed_width': {'height': '150',
#      'width': '200',
#      'size': '157205',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200w.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.gif&ct=g',
#      'mp4_size': '23591',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200w.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.mp4&ct=g',
#      'webp_size': '44574',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200w.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.webp&ct=g'},
#     'fixed_width_downsampled': {'height': '150',
#      'width': '200',
#      'size': '34398',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200w_d.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_d.gif&ct=g',
#      'webp_size': '14602',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200w_d.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_d.webp&ct=g'},
#     'fixed_width_small': {'height': '75',
#      'width': '100',
#      'size': '62563',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100w.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.gif&ct=g',
#      'mp4_size': '9815',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100w.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.mp4&ct=g',
#      'webp_size': '20342',
#      'webp': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100w.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.webp&ct=g'},
#     'fixed_width_small_still': {'height': '75',
#      'width': '100',
#      'size': '2931',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/100w_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w_s.gif&ct=g'},
#     'fixed_width_still': {'height': '150',
#      'width': '200',
#      'size': '6404',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/200w_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_s.gif&ct=g'},
#     'looping': {'mp4_size': '648197',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy-loop.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-loop.mp4&ct=g'},
#     'original_still': {'height': '360',
#      'width': '480',
#      'size': '27055',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy_s.gif&ct=g'},
#     'original_mp4': {'height': '360',
#      'width': '480',
#      'mp4_size': '88655',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.mp4&ct=g'},
#     'preview': {'height': '270',
#      'width': '360',
#      'mp4_size': '25810',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy-preview.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.mp4&ct=g'},
#     'preview_gif': {'height': '63',
#      'width': '84',
#      'size': '46314',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy-preview.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.gif&ct=g'},
#     'preview_webp': {'height': '334',
#      'width': '446',
#      'size': '49680',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy-preview.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.webp&ct=g'},
#     'hd': {'height': '1080',
#      'width': '1440',
#      'mp4_size': '633148',
#      'mp4': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/giphy-hd.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-hd.mp4&ct=g'},
#     '480w_still': {'height': '360',
#      'width': '480',
#      'size': '723813',
#      'url': 'https://media4.giphy.com/media/gRhW4YgNvO6dLeLTf8/480w_s.jpg?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=480w_s.jpg&ct=g'}},
#    'user': {'avatar_url': 'https://media1.giphy.com/avatars/SaltburnFilm/reFLxwwprevN.jpg',
#     'banner_image': '',
#     'banner_url': '',
#     'profile_url': 'https://giphy.com/Saltburnfilm/',
#     'username': 'Saltburnfilm',
#     'display_name': 'Saltburn',
#     'description': "You'll never leave. In select theaters November 17. Everywhere Thanksgiving.",
#     'instagram_url': 'https://instagram.com/saltburnfilm',
#     'website_url': 'https://www.saltburnfilm.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=Z2lmX2lkPWdSaFc0WWdOdk82ZExlTFRmOCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPWdSaFc0WWdOdk82ZExlTFRmOCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPWdSaFc0WWdOdk82ZExlTFRmOCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPWdSaFc0WWdOdk82ZExlTFRmOCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=SENT'}}},
#   {'type': 'gif',
#    'id': 'g5R9dok94mrIvplmZd',
#    'url': 'https://giphy.com/gifs/theoffice-happy-birthday-the-office-happybirthday-g5R9dok94mrIvplmZd',
#    'slug': 'theoffice-happy-birthday-the-office-happybirthday-g5R9dok94mrIvplmZd',
#    'bitly_gif_url': 'https://gph.is/g/4Vyzo03',
#    'bitly_url': 'https://gph.is/g/4Vyzo03',
#    'embed_url': 'https://giphy.com/embed/g5R9dok94mrIvplmZd',
#    'username': 'theoffice',
#    'source': '',
#    'title': 'Happy Birthday Reaction GIF by The Office',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2021-06-17 19:36:07',
#    'trending_datetime': '2021-07-06 21:46:51',
#    'images': {'original': {'height': '400',
#      'width': '480',
#      'size': '2096697',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g',
#      'mp4_size': '538562',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.mp4&ct=g',
#      'webp_size': '585220',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.webp&ct=g',
#      'frames': '30',
#      'hash': '8116ec273da5856e29bed597271264da'},
#     'downsized': {'height': '400',
#      'width': '480',
#      'size': '1301778',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-downsized.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-downsized.gif&ct=g'},
#     'downsized_large': {'height': '400',
#      'width': '480',
#      'size': '2096697',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_medium': {'height': '400',
#      'width': '480',
#      'size': '2096697',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_small': {'height': '242',
#      'width': '290',
#      'mp4_size': '139693',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-downsized-small.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-downsized-small.mp4&ct=g'},
#     'downsized_still': {'height': '400',
#      'width': '480',
#      'size': '46353',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-downsized_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-downsized_s.gif&ct=g'},
#     'fixed_height': {'height': '200',
#      'width': '240',
#      'size': '507322',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.gif&ct=g',
#      'mp4_size': '161949',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.mp4&ct=g',
#      'webp_size': '241706',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.webp&ct=g'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '240',
#      'size': '123564',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200_d.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_d.gif&ct=g',
#      'webp_size': '76210',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200_d.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_d.webp&ct=g'},
#     'fixed_height_small': {'height': '100',
#      'width': '120',
#      'size': '170011',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.gif&ct=g',
#      'mp4_size': '65205',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.mp4&ct=g',
#      'webp_size': '107656',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.webp&ct=g'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '120',
#      'size': '6792',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100_s.gif&ct=g'},
#     'fixed_height_still': {'height': '200',
#      'width': '240',
#      'size': '17721',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_s.gif&ct=g'},
#     'fixed_width': {'height': '167',
#      'width': '200',
#      'size': '387273',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200w.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.gif&ct=g',
#      'mp4_size': '129445',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200w.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.mp4&ct=g',
#      'webp_size': '203902',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200w.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.webp&ct=g'},
#     'fixed_width_downsampled': {'height': '167',
#      'width': '200',
#      'size': '92466',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200w_d.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_d.gif&ct=g',
#      'webp_size': '59268',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200w_d.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_d.webp&ct=g'},
#     'fixed_width_small': {'height': '84',
#      'width': '100',
#      'size': '130410',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100w.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.gif&ct=g',
#      'mp4_size': '49563',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100w.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.mp4&ct=g',
#      'webp_size': '83042',
#      'webp': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100w.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.webp&ct=g'},
#     'fixed_width_small_still': {'height': '84',
#      'width': '100',
#      'size': '5245',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/100w_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w_s.gif&ct=g'},
#     'fixed_width_still': {'height': '167',
#      'width': '200',
#      'size': '14152',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/200w_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_s.gif&ct=g'},
#     'looping': {'mp4_size': '3838006',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-loop.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-loop.mp4&ct=g'},
#     'original_still': {'height': '400',
#      'width': '480',
#      'size': '73605',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy_s.gif&ct=g'},
#     'original_mp4': {'height': '400',
#      'width': '480',
#      'mp4_size': '538562',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.mp4&ct=g'},
#     'preview': {'height': '126',
#      'width': '151',
#      'mp4_size': '45338',
#      'mp4': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-preview.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.mp4&ct=g'},
#     'preview_gif': {'height': '69',
#      'width': '83',
#      'size': '47453',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-preview.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.gif&ct=g'},
#     'preview_webp': {'height': '120',
#      'width': '144',
#      'size': '44088',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/giphy-preview.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.webp&ct=g'},
#     '480w_still': {'height': '400',
#      'width': '480',
#      'size': '2096697',
#      'url': 'https://media2.giphy.com/media/g5R9dok94mrIvplmZd/480w_s.jpg?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=480w_s.jpg&ct=g'}},
#    'user': {'avatar_url': 'https://media1.giphy.com/avatars/theoffice/UYGpbCVMjlBo.jpg',
#     'banner_image': 'https://media1.giphy.com/channel_assets/theoffice/rbxhsCcpp2DW.gif',
#     'banner_url': 'https://media1.giphy.com/channel_assets/theoffice/rbxhsCcpp2DW.gif',
#     'profile_url': 'https://giphy.com/theoffice/',
#     'username': 'theoffice',
#     'display_name': 'The Office',
#     'description': 'The official Giphy page for The Office on Peacock.',
#     'instagram_url': 'https://instagram.com/theoffice',
#     'website_url': 'https://www.peacocktv.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=Z2lmX2lkPWc1Ujlkb2s5NG1ySXZwbG1aZCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPWc1Ujlkb2s5NG1ySXZwbG1aZCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPWc1Ujlkb2s5NG1ySXZwbG1aZCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPWc1Ujlkb2s5NG1ySXZwbG1aZCZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=SENT'}}},
#   {'type': 'gif',
#    'id': 'qbYsmyCoHPdfcs4dm1',
#    'url': 'https://giphy.com/gifs/IntoAction-mental-health-love-yourself-take-care-of-qbYsmyCoHPdfcs4dm1',
#    'slug': 'IntoAction-mental-health-love-yourself-take-care-of-qbYsmyCoHPdfcs4dm1',
#    'bitly_gif_url': 'https://gph.is/g/E3w9e3R',
#    'bitly_url': 'https://gph.is/g/E3w9e3R',
#    'embed_url': 'https://giphy.com/embed/qbYsmyCoHPdfcs4dm1',
#    'username': 'IntoAction',
#    'source': '',
#    'title': 'Be Kind To Yourself Mental Health GIF by INTO ACTION',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2022-12-13 21:12:04',
#    'trending_datetime': '2024-01-09 17:55:10',
#    'images': {'original': {'height': '480',
#      'width': '480',
#      'size': '507238',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g',
#      'mp4_size': '225088',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.mp4&ct=g',
#      'webp_size': '442120',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.webp&ct=g',
#      'frames': '26',
#      'hash': '38cdeadb2afc11e35f30077b689f4c86'},
#     'downsized': {'height': '480',
#      'width': '480',
#      'size': '507238',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_large': {'height': '480',
#      'width': '480',
#      'size': '507238',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_medium': {'height': '480',
#      'width': '480',
#      'size': '507238',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.gif&ct=g'},
#     'downsized_small': {'height': '432',
#      'width': '432',
#      'mp4_size': '111981',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy-downsized-small.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-downsized-small.mp4&ct=g'},
#     'downsized_still': {'height': '480',
#      'width': '480',
#      'size': '507238',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy_s.gif&ct=g'},
#     'fixed_height': {'height': '200',
#      'width': '200',
#      'size': '136891',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.gif&ct=g',
#      'mp4_size': '66729',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.mp4&ct=g',
#      'webp_size': '147662',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200.webp&ct=g'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '200',
#      'size': '40417',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200_d.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_d.gif&ct=g',
#      'webp_size': '42398',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200_d.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_d.webp&ct=g'},
#     'fixed_height_small': {'height': '100',
#      'width': '100',
#      'size': '62938',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.gif&ct=g',
#      'mp4_size': '25799',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.mp4&ct=g',
#      'webp_size': '58832',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100.webp&ct=g'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '100',
#      'size': '3904',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100_s.gif&ct=g'},
#     'fixed_height_still': {'height': '200',
#      'width': '200',
#      'size': '8714',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200_s.gif&ct=g'},
#     'fixed_width': {'height': '200',
#      'width': '200',
#      'size': '136891',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200w.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.gif&ct=g',
#      'mp4_size': '66729',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200w.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.mp4&ct=g',
#      'webp_size': '147662',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200w.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w.webp&ct=g'},
#     'fixed_width_downsampled': {'height': '200',
#      'width': '200',
#      'size': '40417',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200w_d.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_d.gif&ct=g',
#      'webp_size': '42398',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200w_d.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_d.webp&ct=g'},
#     'fixed_width_small': {'height': '100',
#      'width': '100',
#      'size': '62938',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100w.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.gif&ct=g',
#      'mp4_size': '25799',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100w.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.mp4&ct=g',
#      'webp_size': '58832',
#      'webp': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100w.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w.webp&ct=g'},
#     'fixed_width_small_still': {'height': '100',
#      'width': '100',
#      'size': '3904',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/100w_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=100w_s.gif&ct=g'},
#     'fixed_width_still': {'height': '200',
#      'width': '200',
#      'size': '8714',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/200w_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=200w_s.gif&ct=g'},
#     'looping': {'mp4_size': '1017466',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy-loop.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-loop.mp4&ct=g'},
#     'original_still': {'height': '480',
#      'width': '480',
#      'size': '48712',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy_s.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy_s.gif&ct=g'},
#     'original_mp4': {'height': '480',
#      'width': '480',
#      'mp4_size': '225088',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy.mp4&ct=g'},
#     'preview': {'height': '360',
#      'width': '360',
#      'mp4_size': '41487',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy-preview.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.mp4&ct=g'},
#     'preview_gif': {'height': '144',
#      'width': '144',
#      'size': '48630',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy-preview.gif?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.gif&ct=g'},
#     'preview_webp': {'height': '230',
#      'width': '230',
#      'size': '49198',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy-preview.webp?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-preview.webp&ct=g'},
#     'hd': {'height': '1080',
#      'width': '1080',
#      'mp4_size': '1364318',
#      'mp4': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/giphy-hd.mp4?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=giphy-hd.mp4&ct=g'},
#     '480w_still': {'height': '480',
#      'width': '480',
#      'size': '507238',
#      'url': 'https://media1.giphy.com/media/qbYsmyCoHPdfcs4dm1/480w_s.jpg?cid=a49abec2b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl&ep=v1_gifs_trending&rid=480w_s.jpg&ct=g'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/IntoAction/wTEVurMl2S4g.png',
#     'banner_image': 'https://media3.giphy.com/headers/IntoAction/BM0R9Sycv4uM.gif',
#     'banner_url': 'https://media3.giphy.com/headers/IntoAction/BM0R9Sycv4uM.gif',
#     'profile_url': 'https://giphy.com/IntoAction/',
#     'username': 'IntoAction',
#     'display_name': 'INTO ACTION',
#     'description': 'INTO ACTION is a movement of designers, illustrators, animators and artists building cultural momentum around civic engagement and the issues affecting our country and world.',
#     'instagram_url': 'https://instagram.com/intoactionus',
#     'website_url': 'https://www.intoactionlab.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=Z2lmX2lkPXFiWXNteUNvSFBkZmNzNGRtMSZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPXFiWXNteUNvSFBkZmNzNGRtMSZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPXFiWXNteUNvSFBkZmNzNGRtMSZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZ2lmX2lkPXFiWXNteUNvSFBkZmNzNGRtMSZldmVudF90eXBlPUdJRl9UUkVORElORyZjaWQ9YTQ5YWJlYzJiOHRnNzhrbXU4ZzRwdjduNTd1bGN2cXNxc2xqenRtbmZkd29kYWhsJmN0PWc&action_type=SENT'}}}],
#  'pagination': {'total_count': 3540, 'count': 3, 'offset': 0},
#  'meta': {'status': 200,
#   'msg': 'OK',
#   'response_id': 'b8tg78kmu8g4pv7n57ulcvqsqsljztmnfdwodahl'}}

# %%
for gif in response.json()["data"]:
    title = gif["title"]
    trending_date = gif["trending_datetime"]
    url = gif["url"]
    print(f"{title} | {trending_date}\n{url}\n")
# Out:
# Amazon Thank You GIF by Saltburn | 2024-01-09 18:00:07
# https://giphy.com/gifs/primevideo-prime-video-saltburn-salt-burn-gRhW4YgNvO6dLeLTf8
#
# Happy Birthday Reaction GIF by The Office | 2021-07-06 21:46:51
# https://giphy.com/gifs/theoffice-happy-birthday-the-office-happybirthday-g5R9dok94mrIvplmZd
#
# Be Kind To Yourself Mental Health GIF by INTO ACTION | 2024-01-09 17:55:10
# https://giphy.com/gifs/IntoAction-mental-health-love-yourself-take-care-of-qbYsmyCoHPdfcs4dm1

# %%
import os
import configparser
import requests

# Read credentials.cfg file
config = configparser.ConfigParser()
config.read('credentials.cfg')
GIPHY_API_KEY = config['API']['GIPHY']


# REPLACE the following variable with your API Key
API_KEY = GIPHY_API_KEY
#Emoji: https://api.giphy.com/v2/emoji?api_key=&limit=25&offset=0
endpoint = "https://api.giphy.com/v2/emoji"
params = {"api_key": API_KEY, "limit": 3, "offset": 0}
response = requests.get(endpoint, params=params).json()

# %%
for gif in response["data"]:
    title = gif["title"]
    trending_date = gif["trending_datetime"]
    url = gif["url"]
    print(f"{title} | {trending_date}\n{url}\n")
# Out:
# You Got It Yes Sticker by Emoji | 2022-09-07 17:15:10
# https://giphy.com/stickers/Emoji-thumbs-up-emoji-animated-dalJ0CpF7hwmN1nZXe
#
# Wash Hands Corona Sticker by Emoji | 2020-09-17 20:00:03
# https://giphy.com/stickers/Emoji-emoji-wash-hand-washing-ftklTmdD9MN3uXaLvb
#
# Peace Hands Sticker by Emoji | 2021-04-01 05:00:05
# https://giphy.com/stickers/Emoji-transparent-4tSHBpzJw7R3rrKUeo

# %% [markdown]
# ```Text
# Now, say you want to make a script that allows you to search for a specific word and fetch the first GIPHY match for that word. A different endpoint and slight variation of the code above can do that quite quickly:
# ```

# %%
import os
import configparser
import requests

# Read credentials.cfg file
config = configparser.ConfigParser()
config.read('credentials.cfg')
GIPHY_API_KEY = config['API']['GIPHY']

# REPLACE the following variable with your API Key
API_KEY = GIPHY_API_KEY
#Search: https://api.giphy.com/v1/gifs/search?api_key=r&q=&limit=25&offset=0&rating=g&lang=en&bundle=messaging_non_clips
endpoint = "https://api.giphy.com/v1/gifs/search"

search_term = "shrug"
params = {"api_key": API_KEY, "limit": 1, "q": search_term, "rating": "g"}
response = requests.get(endpoint, params=params).json()
for gif in response["data"]:
    title = gif["title"]
    url = gif["url"]
    print(f"{title} | {url}")
# Out:
# Season 5 Idk GIF by Paramount+ | https://giphy.com/gifs/CBSAllAccess-season-5-episode-23-i-love-lucy-JRhS6WoswF8FxE0g2R

# %% [markdown]
# `Searching Google Books`
#
# - For this example, you’ll use the `Google Books API` and the `public volumes endpoint` to search for books.
#   - [Google Books API](https://developers.google.com/books)
#   - [Public Volumes Endpoint](https://developers.google.com/books/docs/v1/using#WorkingVolumes)

# %%
# https://www.googleapis.com/books/v1/volumes?q=search+terms
# https://www.googleapis.com/books/v1/volumes?q=flowers+inauthor:keyes&key=yourAPIKey

# %%
# Here’s a straightforward piece of code to look for the words "moby dick" in the whole catalog:
import os
import configparser
import requests

# Read credentials.cfg file
config = configparser.ConfigParser()
config.read('credentials.cfg')
GBOOKS_API_KEY = config['API']['GOOGLE_BOOKS']

# REPLACE the following variable with your API Key
API_KEY = GBOOKS_API_KEY
endpoint = "https://www.googleapis.com/books/v1/volumes"

search_term = "moby dick"
params = {"q": search_term, "maxResults": 3}
response = requests.get(endpoint, params=params).json()
response
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 2460,
#  'items': [{'kind': 'books#volume',
#    'id': 'EIN6AgAAQBAJ',
#    'etag': 'fu0v630/GYo',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/EIN6AgAAQBAJ',
#    'volumeInfo': {'title': 'Moby Dick',
#     'authors': ['Herman Melville'],
#     'publisher': 'ABDO Publishing Company',
#     'publishedDate': '2010-01-01',
#     'description': "In Herman Melville's classic tale of revenge, Ishmael tells his story of becoming a whaler on the Pequod. When Ishmael and his unexpected friend Queequeg join Captain Ahab's hunt for Moby Dick, the voyage of a lifetime turns into tragedy. The adventures of sailing the seas on the hunt for the great white whale is retold in the Calico Illustrated Classics adaptation of Melville's Moby Dick. Calico Chapter Books is an imprint of Magic Wagon, a division of ABDO Group. Grades 3-8.",
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781617864124'},
#      {'type': 'ISBN_10', 'identifier': '1617864129'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 114,
#     'printType': 'BOOK',
#     'categories': ['Juvenile Fiction'],
#     'averageRating': 5,
#     'ratingsCount': 3,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=EIN6AgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=EIN6AgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=EIN6AgAAQBAJ&printsec=frontcover&dq=moby+dick&hl=&cd=1&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=EIN6AgAAQBAJ&dq=moby+dick&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Moby_Dick.html?hl=&id=EIN6AgAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Moby_Dick-sample-pdf.acsm?id=EIN6AgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=EIN6AgAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'In Herman Melville&#39;s classic tale of revenge, Ishmael tells his story of becoming a whaler on the Pequod. When Ishmael and his unexpected friend Queequeg join Captain Ahab&#39;s hunt for Moby Dick, the voyage of a lifetime turns into tragedy.'}},
#   {'kind': 'books#volume',
#    'id': 'K-dvDwAAQBAJ',
#    'etag': 'Sl3oZJmLd9o',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/K-dvDwAAQBAJ',
#    'volumeInfo': {'title': 'Why Read Moby-Dick?',
#     'authors': ['Nathaniel Philbrick'],
#     'publisher': 'Penguin',
#     'publishedDate': '2013-09-24',
#     'description': "A “brilliant and provocative” (The New Yorker) celebration of Melville’s masterpiece—from the bestselling author of In the Heart of the Sea, Valiant Ambition, and In the Hurricane's Eye One of the greatest American novels finds its perfect contemporary champion in Why Read Moby-Dick?, Nathaniel Philbrick’s enlightening and entertaining tour through Melville’s classic. As he did in his National Book Award–winning bestseller In the Heart of the Sea, Philbrick brings a sailor’s eye and an adventurer’s passion to unfolding the story behind an epic American journey. He skillfully navigates Melville’s world and illuminates the book’s humor and unforgettable characters—finding the thread that binds Ishmael and Ahab to our own time and, indeed, to all times. An ideal match between author and subject, Why Read Moby-Dick? will start conversations, inspire arguments, and make a powerful case that this classic tale waits to be discovered anew. “Gracefully written [with an] infectious enthusiasm…”—New York Times Book Review",
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780143123972'},
#      {'type': 'ISBN_10', 'identifier': '0143123971'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 146,
#     'printType': 'BOOK',
#     'categories': ['Literary Criticism'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=K-dvDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=K-dvDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=K-dvDwAAQBAJ&printsec=frontcover&dq=moby+dick&hl=&cd=2&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=K-dvDwAAQBAJ&dq=moby+dick&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Why_Read_Moby_Dick.html?hl=&id=K-dvDwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=K-dvDwAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'An ideal match between author and subject, Why Read Moby-Dick? will start conversations, inspire arguments, and make a powerful case that this classic tale waits to be discovered anew. “Gracefully written [with an] infectious ...'}},
#   {'kind': 'books#volume',
#    'id': '-xGdZ3pYjtkC',
#    'etag': 'rRly7pd+vN4',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/-xGdZ3pYjtkC',
#    'volumeInfo': {'title': 'Moby Dick',
#     'authors': ['Herman Melville'],
#     'publishedDate': '1989',
#     'description': 'A young seaman joins the crew of the fanatical Captain Ahab in pursuit of the white whale Moby Dick.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0895773228'},
#      {'type': 'ISBN_13', 'identifier': '9780895773227'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 496,
#     'printType': 'BOOK',
#     'categories': ['Adventure stories'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.2.1.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=-xGdZ3pYjtkC&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=-xGdZ3pYjtkC&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=-xGdZ3pYjtkC&q=moby+dick&dq=moby+dick&hl=&cd=3&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=-xGdZ3pYjtkC&dq=moby+dick&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Moby_Dick.html?hl=&id=-xGdZ3pYjtkC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=-xGdZ3pYjtkC&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'A young seaman joins the crew of the fanatical Captain Ahab in pursuit of the white whale Moby Dick.'}}]}

# %%
for book in response["items"]:
    volume = book["volumeInfo"]
    title = volume['title']
    published = volume['publishedDate']
    description = volume['description']
    print(f"{title} ({published})\n{description}\n")
# Out:
# Moby Dick (2010-01-01)
# In Herman Melville's classic tale of revenge, Ishmael tells his story of becoming a whaler on the Pequod. When Ishmael and his unexpected friend Queequeg join Captain Ahab's hunt for Moby Dick, the voyage of a lifetime turns into tragedy. The adventures of sailing the seas on the hunt for the great white whale is retold in the Calico Illustrated Classics adaptation of Melville's Moby Dick. Calico Chapter Books is an imprint of Magic Wagon, a division of ABDO Group. Grades 3-8.
#
# Why Read Moby-Dick? (2013-09-24)
# A “brilliant and provocative” (The New Yorker) celebration of Melville’s masterpiece—from the bestselling author of In the Heart of the Sea, Valiant Ambition, and In the Hurricane's Eye One of the greatest American novels finds its perfect contemporary champion in Why Read Moby-Dick?, Nathaniel Philbrick’s enlightening and entertaining tour through Melville’s classic. As he did in his National Book Award–winning bestseller In the Heart of the Sea, Philbrick brings a sailor’s eye and an adventurer’s passion to unfolding the story behind an epic American journey. He skillfully navigates Melville’s world and illuminates the book’s humor and unforgettable characters—finding the thread that binds Ishmael and Ahab to our own time and, indeed, to all times. An ideal match between author and subject, Why Read Moby-Dick? will start conversations, inspire arguments, and make a powerful case that this classic tale waits to be discovered anew. “Gracefully written [with an] infectious enthusiasm…”—New York Times Book Review
#
# Moby Dick (1989)
# A young seaman joins the crew of the fanatical Captain Ahab in pursuit of the white whale Moby Dick.

# %%
import os
import configparser
import requests

# Read credentials.cfg file
config = configparser.ConfigParser()
config.read('credentials.cfg')
GBOOKS_API_KEY = config['API']['GOOGLE_BOOKS']

# REPLACE the following variable with your API Key
API_KEY = GBOOKS_API_KEY
endpoint = "https://www.googleapis.com/books/v1/volumes"

search_term = "The Millionaire Next Door"
params = {"key": GBOOKS_API_KEY, "q": search_term, "maxResults": 3}
response = requests.get(endpoint, params=params).json()
response
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 2752,
#  'items': [{'kind': 'books#volume',
#    'id': 'DzytDwAAQBAJ',
#    'etag': 'EDqpXQZd23c',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DzytDwAAQBAJ',
#    'volumeInfo': {'title': 'The Millionaire Next Door',
#     'authors': ['Thomas J. Stanley', 'William D. Danko'],
#     'publisher': 'Rosetta Books',
#     'publishedDate': '2010-11-30',
#     'description': 'How do the rich get rich? An updated edition of the “remarkable” New York Times bestseller, based on two decades of research (The Washington Post). Most of the truly wealthy in the United States don’t live in Beverly Hills or on Park Avenue. They live next door. America’s wealthy seldom get that way through an inheritance or an advanced degree. They bargain-shop for used cars, raise children who don’t realize how rich their families are, and reject a lifestyle of flashy exhibitionism and competitive spending. In fact, the glamorous people many of us think of as “rich” are actually a tiny minority of America’s truly wealthy citizens—and behave quite differently than the majority. At the time of its first publication, The Millionaire Next Door was a groundbreaking examination of America’s rich—exposing for the first time the seven common qualities that appear over and over among this exclusive demographic. This edition includes a new foreword by Dr. Thomas J. Stanley—updating the original content in the context of the financial crash and the twenty-first century. “Their surprising results reveal fundamental qualities of this group that are diametrically opposed to today’s earn-and-consume culture.” —Library Journal',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780795314865'},
#      {'type': 'ISBN_10', 'identifier': '0795314868'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 307,
#     'printType': 'BOOK',
#     'categories': ['Business & Economics'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '0.4.4.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=DzytDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=DzytDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=DzytDwAAQBAJ&printsec=frontcover&dq=The+Millionaire+Next+Door&hl=&cd=1&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=DzytDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=DzytDwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 19.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 19.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=DzytDwAAQBAJ&rdid=book-DzytDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 19990000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 19990000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/The_Millionaire_Next_Door-sample-epub.acsm?id=DzytDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/The_Millionaire_Next_Door-sample-pdf.acsm?id=DzytDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=DzytDwAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This edition includes a new foreword by Dr. Thomas J. Stanley—updating the original content in the context of the financial crash and the twenty-first century. “Their surprising results reveal fundamental qualities of this group that ...'}},
#   {'kind': 'books#volume',
#    'id': 'ck1nDwAAQBAJ',
#    'etag': 'uBk0r6j2kZw',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/ck1nDwAAQBAJ',
#    'volumeInfo': {'title': 'The Next Millionaire Next Door',
#     'subtitle': 'Enduring Strategies for Building Wealth',
#     'authors': ['Thomas J. Stanley, Ph.D.', 'Sarah Stanley Fallaw, Ph.D'],
#     'publisher': 'Rowman & Littlefield',
#     'publishedDate': '2018-10-01',
#     'description': 'Is the millionaire next door still out there today? The latest research from Dr. Thomas J. Stanley and his daughter, Dr. Sarah Stanley Fallaw, confirms that, yes, the millionaire next door is alive and well. And he’s achieving his financial objectives much the same way he always has: by living below his means, being a contrarian in a maelstrom of hyper-consumption, and being disciplined in reaching his financial goals. The book examines wealth in America 20 years after Dr. Stanley’s groundbreaking work on self-made affluence. While a new generation of household financial managers are being inundated with the proliferation financial advice, The Next Millionaire Next Door provides readers with an analysis of what it takes to achieve wealth with data-based conclusions and evidence from those who have built wealth on their own over the last two decades. In this current work, the authors detail how specific decisions, behaviors, and characteristics align with the discipline of wealth building, covering areas such as consumption, budgeting, careers, investing, and financial management in general. Through case studies, survey research, and a careful examination of quantitative studies of wealth, the authors illustrate what it takes to achieve financial success today, regardless of market conditions or rising costs.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781493035366'},
#      {'type': 'ISBN_10', 'identifier': '1493035363'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 272,
#     'printType': 'BOOK',
#     'categories': ['Business & Economics'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.4.4.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=ck1nDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=ck1nDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=ck1nDwAAQBAJ&printsec=frontcover&dq=The+Millionaire+Next+Door&hl=&cd=2&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=ck1nDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=ck1nDwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 16, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 16, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=ck1nDwAAQBAJ&rdid=book-ck1nDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 16000000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 16000000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/The_Next_Millionaire_Next_Door-sample-epub.acsm?id=ck1nDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/The_Next_Millionaire_Next_Door-sample-pdf.acsm?id=ck1nDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=ck1nDwAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'In this book the authors highlight how specific decisions, behaviors, and characteristics align with the discipline of wealth building, covering areas such as consumption, budgeting, careers, investing, and financial management in general.'}},
#   {'kind': 'books#volume',
#    'id': 'DTytDwAAQBAJ',
#    'etag': '4fKXP8wnBYM',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DTytDwAAQBAJ',
#    'volumeInfo': {'title': 'Millionaire Women Next Door',
#     'authors': ['Thomas J. Stanley'],
#     'publisher': 'Rosetta Books',
#     'publishedDate': '2010-11-25',
#     'description': 'The New York Times–bestselling author of The Millionaire Next Door reveals the spending and saving habits of financially successful women. Millionaire Women Next Door presents a variety of groundbreaking concepts involving the personality, lifestyle, motives, beliefs, and spending habits of economically successful American businesswomen. Most of these women report being raised in nurturing family environments. They were trained not only to succeed financially but also to be generous in giving to noble causes. Stanley asks, “How did these businesswomen become millionaires? They did it by doing more of the key activities and achieving better results than most of their male counterparts.” Praise for Thomas J. Stanley’s The Millionaire Mind “A very good book that deserves to be well read.” —The Wall Street Journal “Worth every cent . . . It’s an inspiration for anyone who has ever been told that he wasn’t smart enough or good enough.” —Associated Press “A high IQ isn’t necessarily an indicator of financial success . . . Stanley tells us that the typical millionaire had an average GPA and frugal spending habits—but good interpersonal skills.” —Entertainment Weekly “Ideas bigger than the next buck.” —Orlando Sentinel',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780795314896'},
#      {'type': 'ISBN_10', 'identifier': '0795314892'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 277,
#     'printType': 'BOOK',
#     'categories': ['Business & Economics'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.4.4.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=DTytDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=DTytDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=DTytDwAAQBAJ&printsec=frontcover&dq=The+Millionaire+Next+Door&hl=&cd=3&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=DTytDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=DTytDwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 19.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 19.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=DTytDwAAQBAJ&rdid=book-DTytDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 19990000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 19990000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Millionaire_Women_Next_Door-sample-epub.acsm?id=DTytDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Millionaire_Women_Next_Door-sample-pdf.acsm?id=DTytDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=DTytDwAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Millionaire Women Next Door presents a variety of groundbreaking concepts involving the personality, lifestyle, motives, beliefs, and spending habits of economically successful American businesswomen.'}}]}
